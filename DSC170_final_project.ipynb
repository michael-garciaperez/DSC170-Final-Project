# %% [markdown]
# ## Exploring the Impact of Computer Ownership on Unemployment in San Diego, CA
# By: Michael Garcia-Perez & Haoyu Fu

# %% [markdown]
# ### Table of Contents
# To return to the table of contents, click on the number at any major section heading.

# %% [markdown]
# [1. Introduction](#1.-Introduction)
#
# [2. Exploratory Data Analysis](#2.-Exploratory-Data-Analysis)
#
# [3. Model Development & Evaluation](#3.-Model-Development-&-Evaluation)
#
# [4. Results Summary](#4.-Results-Summary)
#
# [5. Conclusion & Discussion](#5.-Conclusion-&-Discussion)

# %% [markdown]
# ### [1.](#Table-of-Contents) Introduction

# %%
# Importing necessary packages
import pandas as pd
import geopandas as gpd

# %%
# Reading all CSV files into GeoDataFrames
employment_centers = gpd.read_file('Employment_Centers_V2_Landing_Page_Data_20240226.csv')
computer_ownership = gpd.read_file('SDG_Indicator_5.b.1_Data_-_Computer_Ownership_20240226.csv')
employee_resident_survey = gpd.read_file('Telework_-_SANDAG_Employee_Resident_Study_2023_20240226.csv')
unemployment = gpd.read_file('Unemployment_20240226.csv')
business_tax_certificates = gpd.read_file('sd_businesses_active_datasd.csv')

broadband1 = gpd.read_file('Digital_Divide_-_Broadband_Cost_with_Coastline_20240307.csv')
broadband2 = gpd.read_file('Digital_Divide_-_Broadband_Providers_Meeting_Federal_Threshold_20240307.csv')
broadband3 = gpd.read_file('Digital_Divide_-_Fixed_Broadband_Meets_Federal_Threshold_20240307.csv')
broadband4 = gpd.read_file('Digital_Divide_-_Household_Broadband_Adoption__Low-Income_Households_20240307.csv')
broadband5 = gpd.read_file('Digital_Divide_-_Household_Broadband_Adoption__Minority_Populations_20240307.csv')
broadband6 = gpd.read_file('Digital_Divide_2.0_Scoring_Data_20240307.csv')
broadband7 = gpd.read_file('Digital_Divide_-_Household_Broadband_Adoption__Seniors_20240308.csv')

county_borders = gpd.read_file('san_diego_boundary_datasd.shx')

# %%
employment_centers = employment_centers.drop(columns=['geometry'])
computer_ownership = computer_ownership.drop(columns=['geometry'])
employee_resident_survey = employee_resident_survey.drop(columns=['geometry'])
unemployment = unemployment.drop(columns=['geometry'])
business_tax_certificates = business_tax_certificates.drop(columns=['geometry'])

# %% [markdown]
# ### [2.](#Table-of-Contents) Exploratory Data Analysis

# %%
employment_centers
# Out:
#                                              the_geom EC_ID    Tier  \
# 0   MULTIPOLYGON (((-117.23022929489473 32.7101188...     1  Tier 2
# 1   MULTIPOLYGON (((-116.74770267058798 32.8308206...     2  Tier 4
# 2   MULTIPOLYGON (((-117.12322200015252 32.6909329...     3  Tier 4
# 3   MULTIPOLYGON (((-117.2649316164375 33.12364806...     4  Tier 2
# 4   MULTIPOLYGON (((-117.32240958006133 33.1117936...     5  Tier 3
# ..                                                ...   ...     ...
# 86  MULTIPOLYGON (((-117.2370000827015 32.67530400...    95  Tier 4
# 87  MULTIPOLYGON (((-116.85871483176943 32.9558522...   101  Tier 4
# 88  MULTIPOLYGON (((-116.94809604700163 33.2560918...   102  Tier 4
# 89  MULTIPOLYGON (((-117.08292620452602 33.3617855...   103  Tier 4
# 90  MULTIPOLYGON (((-116.84124679756688 32.7749620...   104  Tier 4
#
#                                    Name Total Employees  \
# 0                    San Diego Bayfront           34291
# ...

# %% [markdown]
# ### [3.](#Table-of-Contents) Model Development & Evaluation

# %% [markdown]
# ### [4.](#Table-of-Contents) Results Summary

# %% [markdown]
# ### [5.](#Table-of-Contents) Conclusion & Discussion
